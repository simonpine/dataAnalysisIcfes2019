# %%
import pandas as pd

# %%
df = pd.read_csv('https://www.datos.gov.co/resource/ynam-yc42.csv')

# %%
df.head()
# Out:
#   estu_tipodocumento estu_nacionalidad estu_genero     estu_fechanacimiento  \
# 0                 TI          COLOMBIA           M  2002-02-18T00:00:00.000
# 1                 TI          COLOMBIA           M  2003-06-28T00:00:00.000
# 2                 TI          COLOMBIA           M  2001-06-02T00:00:00.000
# 3                 TI          COLOMBIA           M  2002-04-26T00:00:00.000
# 4                 TI          COLOMBIA           M  2002-02-05T00:00:00.000
#
#    periodo  estu_consecutivo estu_estudiante estu_tieneetnia estu_pais_reside  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# 2    20194  SB11201940255017      ESTUDIANTE              No         COLOMBIA
# 3    20194  SB11201940154799      ESTUDIANTE              Si         COLOMBIA
# 4    20194  SB11201940280831      ESTUDIANTE              No         COLOMBIA
#
# ...

# %%
df.describe(include='object')
# Out:
#        estu_tipodocumento estu_nacionalidad estu_genero  \
# count                1000              1000        1000
# unique                  7                 2           3
# top                    TI          COLOMBIA           M
# freq                  719               992         676
#
#            estu_fechanacimiento  estu_consecutivo estu_estudiante  \
# count                      1000              1000            1000
# unique                      737              1000               1
# top     1900-01-01T00:00:00.000  SB11201940255487      ESTUDIANTE
# freq                          7                 1            1000
#
#        estu_tieneetnia estu_pais_reside estu_etnia estu_depto_reside  ...  \
# count             1000             1000       1000               999  ...
# unique               3                2         14                33  ...
# top                 No         COLOMBIA          -         ATLANTICO  ...
# ...

# %%
df.estu_genero.unique()
# Out:
# array(['M', 'F', '-'], dtype=object)

# %%
df[['estu_genero', 'estu_tieneetnia']]
# Out:
#     estu_genero estu_tieneetnia
# 0             M              No
# 1             M              No
# 2             M              No
# 3             M              Si
# 4             M              No
# ..          ...             ...
# 995           M              No
# 996           M              No
# 997           M              No
# 998           M              No
# 999           M              No
#
# [1000 rows x 2 columns]

# %%
df[(df['estu_genero'] == 'F') & (df['estu_tieneetnia'] == 'Si')]
# Out:
#     estu_tipodocumento estu_nacionalidad estu_genero     estu_fechanacimiento  \
# 28                  CC          COLOMBIA           F  1999-12-01T00:00:00.000
# 52                  TI          COLOMBIA           F  2003-02-13T00:00:00.000
# 176                 TI          COLOMBIA           F  2001-06-17T00:00:00.000
# 215                 CC          COLOMBIA           F  2000-04-30T00:00:00.000
# 223                 CC          COLOMBIA           F  1999-09-06T00:00:00.000
# 225                 TI          COLOMBIA           F  2002-04-27T00:00:00.000
# 240                 CC          COLOMBIA           F  2000-03-14T00:00:00.000
# 261                 TI          COLOMBIA           F  2001-11-06T00:00:00.000
# 468                 CC          COLOMBIA           F  2001-04-20T00:00:00.000
# 470                 TI          COLOMBIA           F  2003-04-21T00:00:00.000
# 486                 TI          COLOMBIA           F  2003-01-01T00:00:00.000
# ...

# %%
df.isnull().sum()
# Out:
# estu_tipodocumento           0
# estu_nacionalidad            0
# estu_genero                  0
# estu_fechanacimiento         0
# periodo                      0
#                             ..
# estu_inse_individual         0
# estu_nse_individual         48
# estu_nse_establecimiento     0
# estu_estadoinvestigacion     0
# estu_generacion_e            0
# Length: 82, dtype: int64

# %%
df['NewColumn'] = df['estu_genero'].apply(lambda x: True if x == 'F' else False) + df['estu_tieneetnia'].apply(lambda x: True if x == 'Si' else False)
# df['NewColumn'] = df[['ESTU_GENERO', 'ESTU_TIENEETNIA']].apply(lambda x,y: True if x == 'F' else False)
# Out:
# C:\Users\simon\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(

# %%
df.head()
# Out:
#   estu_tipodocumento estu_nacionalidad estu_genero     estu_fechanacimiento  \
# 0                 TI          COLOMBIA           M  2002-02-18T00:00:00.000
# 1                 TI          COLOMBIA           M  2003-06-28T00:00:00.000
# 2                 TI          COLOMBIA           M  2001-06-02T00:00:00.000
# 3                 TI          COLOMBIA           M  2002-04-26T00:00:00.000
# 4                 TI          COLOMBIA           M  2002-02-05T00:00:00.000
#
#    periodo  estu_consecutivo estu_estudiante estu_tieneetnia estu_pais_reside  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# 2    20194  SB11201940255017      ESTUDIANTE              No         COLOMBIA
# 3    20194  SB11201940154799      ESTUDIANTE              Si         COLOMBIA
# 4    20194  SB11201940280831      ESTUDIANTE              No         COLOMBIA
#
# ...

# %%
df[['estu_genero', 'estu_tieneetnia']].value_counts().plot.pie(subplots=True, figsize=(5, 5))
# Out:
# array([<AxesSubplot:ylabel='None'>], dtype=object)

# %%
df[['estu_genero', 'estu_tieneetnia']].value_counts().plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='estu_genero,estu_tieneetnia'>
